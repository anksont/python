# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\CGWB\\data_TS.csv",index_col="Taluk")

# %%
df.info()
df.describe()

from matplotlib.backends.backend_pdf import PdfPages
#with PdfPages("CGWB RAINFALL ANALYSIS") as pdf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, Jan-13 to Dec-15
# Data columns (total 31 columns):
# BANGALORE          36 non-null int64
# BANGALORE ?        36 non-null int64
# RAMANAGAR          36 non-null int64
# CHITRADURGA        36 non-null int64
# DAVANAGERE         36 non-null int64
# KOLAR              36 non-null int64
# CHIKKABALLAPURA    36 non-null int64
# SHIMOGA            36 non-null int64
# TUMKUR             36 non-null int64
# CHAMARAJANAGARA    36 non-null int64
# CHIKKAMAGALUR      36 non-null int64
# D.KANNADA          36 non-null int64
# HASSAN             36 non-null int64
# KODAGU             36 non-null int64
# MANDYA             36 non-null int64
# MYSORE             36 non-null int64
# UDUPI              36 non-null int64
# BELLARY            36 non-null int64
# BIDAR              36 non-null int64
# GULBARGA           36 non-null int64
# YADGIR             36 non-null int64
# KOPPALA            36 non-null int64
# ...

# %%
print("column names",df.iloc[:,1:].columns)
df.dtypes
print("range index " ,df.index)
print(df.iteritems)
#for key,data in df.iteritems():
#    print(key)
#    print(data)

#df
#df.columns=["DATE",df.iloc[:,1:].columns]
# Out:
# column names Index(['BANGALORE ?', 'RAMANAGAR', 'CHITRADURGA', 'DAVANAGERE', 'KOLAR',
#        'CHIKKABALLAPURA', 'SHIMOGA', 'TUMKUR', 'CHAMARAJANAGARA',
#        'CHIKKAMAGALUR', 'D.KANNADA', 'HASSAN', 'KODAGU', 'MANDYA', 'MYSORE',
#        'UDUPI', 'BELLARY', 'BIDAR', 'GULBARGA', 'YADGIR', 'KOPPALA', 'RAICHUR',
#        'BAGALKOTE', 'BELGAUM', 'BIJAPUR', 'DHARWAD', 'GADAG', 'HAVERI',
#        'UTTRA KANNADA', 'STATE'],
#       dtype='object')
# range index  Index(['Jan-13', 'Feb-13', 'Mar-13', 'Apr-13', 'May-13', 'Jun-13', 'Jul-13',
#        'Aug-13', 'Sep-13', 'Oct-13', 'Nov-13', 'Dec-13', 'Jan-14', 'Feb-14',
#        'Mar-14', 'Apr-14', 'May-14', 'Jun-14', 'Jul-14', 'Aug-14', 'Sep-14',
#        'Oct-14', 'Nov-14', 'Dec-14', 'Jan-15', 'Feb-15', 'Mar-15', 'Apr-15',
#        'May-15', 'Jun-15', 'Jul-15', 'Aug-15', 'Sep-15', 'Oct-15', 'Nov-15',
#        'Dec-15'],
#       dtype='object', name='Taluk')
# ...

# %%
print(df.get_ftype_counts())
df.cov()
df.corr()
# Out:
# int64:dense    31
# dtype: int64
# C:\Users\ankit\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: get_ftype_counts is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#                  BANGALORE  BANGALORE ?  RAMANAGAR  CHITRADURGA  DAVANAGERE  \
# BANGALORE         1.000000     0.917931   0.894576     0.719028    0.687253
# BANGALORE ?       0.917931     1.000000   0.935958     0.854363    0.716413
# RAMANAGAR         0.894576     0.935958   1.000000     0.764869    0.676080
# CHITRADURGA       0.719028     0.854363   0.764869     1.000000    0.817913
# DAVANAGERE        0.687253     0.716413   0.676080     0.817913    1.000000
# KOLAR             0.891184     0.832454   0.829192     0.554181    0.482878
# CHIKKABALLAPURA   0.847785     0.835244   0.812642     0.708000    0.602662
# SHIMOGA           0.268331     0.361367   0.249786     0.521063    0.538649
# ...

# %%
df.memory_usage()
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (36, 31)

# %%
df.index.name="DATE" # columns name change

# %%
df
# Out:
#         BANGALORE  BANGALORE ?  RAMANAGAR  CHITRADURGA  DAVANAGERE  KOLAR  \
# DATE
# Jan-13          0            0          0            0           0      0
# Feb-13          7            7          0            4           3      0
# Mar-13          0            2          8            5          21      4
# Apr-13         19           33         72           23          29     50
# May-13          0            0          0            0           0      0
# Jun-13          9           18         11           18          32     26
# Jul-13         70           74         74           40          47    119
# Aug-13        142          131         93          165         111    101
# Sep-13         41           48         45           53          63     49
# Oct-13         67           87         89           45          29    117
# Nov-13         94          105         97           95         137     99
# Dec-13         24           14         14            0           0     21
# ...

# %%
fig=plt.figure(figsize=(12,12))
sns.boxplot(data=df)
plt.xlabel("DISTRICTS")
plt.ylabel("RAINFALL in KARNATAKA (in mm)")
plt.xticks(rotation=90)
plt.title("RAINFALL in KARNATAKA (in mm) vs DISTRICT")
# Out:
# Text(0.5,1,'RAINFALL in KARNATAKA (in mm) vs DISTRICT')

# %%
c=df.copy(deep=True)

# %%
c
# Out:
#         BANGALORE  BANGALORE ?  RAMANAGAR  CHITRADURGA  DAVANAGERE  KOLAR  \
# DATE
# Jan-13          0            0          0            0           0      0
# Feb-13          7            7          0            4           3      0
# Mar-13          0            2          8            5          21      4
# Apr-13         19           33         72           23          29     50
# May-13          0            0          0            0           0      0
# Jun-13          9           18         11           18          32     26
# Jul-13         70           74         74           40          47    119
# Aug-13        142          131         93          165         111    101
# Sep-13         41           48         45           53          63     49
# Oct-13         67           87         89           45          29    117
# Nov-13         94          105         97           95         137     99
# Dec-13         24           14         14            0           0     21
# ...

# %%
import datetime
start=datetime.datetime(2013,1,31)
end=datetime.datetime(2015,12,31)
index=pd.date_range(start,end,freq='M')
index
df.index=index
df
# Out:
#             BANGALORE  BANGALORE ?  RAMANAGAR  CHITRADURGA  DAVANAGERE  KOLAR  \
# 2013-01-31          0            0          0            0           0      0
# 2013-02-28          7            7          0            4           3      0
# 2013-03-31          0            2          8            5          21      4
# 2013-04-30         19           33         72           23          29     50
# 2013-05-31          0            0          0            0           0      0
# 2013-06-30          9           18         11           18          32     26
# 2013-07-31         70           74         74           40          47    119
# 2013-08-31        142          131         93          165         111    101
# 2013-09-30         41           48         45           53          63     49
# 2013-10-31         67           87         89           45          29    117
# 2013-11-30         94          105         97           95         137     99
# ...

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %%
for i in df.columns:
    fig=plt.figure(figsize=(12,5))
    ax=fig.add_subplot(111)
    x_1="plot_%s",i
    x_1=ax.plot(df.index,df[i])
    ax.set_xlabel("month".upper())
    ax.set_ylabel("average rainfall in month".upper())
    ax.set_title("MONTHLY RAINFALL FROM 2013-15")
    ax.legend()
plt.show
# Out:
# C:\Users\ankit\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.plot(figsize=(12,10))
plt.xlabel("month".upper())
plt.ylabel("district average rainfall in month".upper())
plt.title("MONTHLY RAINFALL FROM 2013-15")
plt.legend(fontsize='x-small')
plt.savefig("MONTHLY RAINFALL FROM 2013-15.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.columns
# Out:
# Index(['BANGALORE', 'BANGALORE ?', 'RAMANAGAR', 'CHITRADURGA', 'DAVANAGERE',
#        'KOLAR', 'CHIKKABALLAPURA', 'SHIMOGA', 'TUMKUR', 'CHAMARAJANAGARA',
#        'CHIKKAMAGALUR', 'D.KANNADA', 'HASSAN', 'KODAGU', 'MANDYA', 'MYSORE',
#        'UDUPI', 'BELLARY', 'BIDAR', 'GULBARGA', 'YADGIR', 'KOPPALA', 'RAICHUR',
#        'BAGALKOTE', 'BELGAUM', 'BIJAPUR', 'DHARWAD', 'GADAG', 'HAVERI',
#        'UTTRA KANNADA', 'STATE'],
#       dtype='object')

# %%
df_nek=df[['BELLARY','BIDAR', 'CHITRADURGA','GULBARGA','KOPPALA','RAICHUR','YADGIR', 'STATE']]

# %%
g=df_nek.describe()

#import PyPDF2

###pdf = fpdf.FPDF(format='letter')
#pdf.add_page(orientation=None)#
#pdf.set_font("Arial", size=12)

#for i in str(g):
#    pdf.write(8,i)
#    pdf.ln()
#pdf.output("C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\CGWB\\CGWB ANALYSIS REPORT.pdf")###

# %%
g.shape
# Out:
# (8, 8)

# %%
datatoexcel=pd.ExcelWriter("C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\CGWB\\CGWB ANALYSIS REPORT.xlsx",engine="xlsxwriter")
g.to_excel(datatoexcel,sheet_name='Sheet1')

# %%
sns.boxplot(data=g)

# %%
g_1=g.T

# %%
g_1.plot(kind="bar")

# %%
g.columns
# Out:
# Index(['BELLARY', 'BIDAR', 'CHITRADURGA', 'GULBARGA', 'KOPPALA', 'RAICHUR',
#        'YADGIR', 'STATE'],
#       dtype='object')

# %%
g
# Out:
#           BELLARY       BIDAR  CHITRADURGA    GULBARGA     KOPPALA  \
# count   36.000000   36.000000    36.000000   36.000000   36.000000
# mean    47.222222   58.027778    54.527778   55.777778   48.000000
# std     49.926867   60.727253    58.245042   59.242413   55.185402
# min      0.000000    0.000000     0.000000    0.000000    0.000000
# 25%      4.500000    6.500000     4.750000    6.750000    7.000000
# 50%     28.000000   39.000000    38.000000   36.000000   26.000000
# 75%     86.000000   97.250000    78.750000   94.500000   78.250000
# max    169.000000  228.000000   189.000000  248.000000  226.000000
#
#           RAICHUR      YADGIR       STATE
# count   36.000000   36.000000   36.000000
# mean    40.555556   50.333333   85.250000
# std     61.118828   58.449490   82.094153
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    8.750000
# 50%     22.500000   35.000000   78.000000
# 75%     56.250000   75.750000  135.500000
# ...

# %%
# simple_demo.py
 
from fpdf import FPDF
 
pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=12)
pdf.cell(200, 10, txt=str(g.all()), ln=1, align="C")
pdf.output("simple_demo.pdf")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-4dd898045a5f> in <module>()
#       1 # simple_demo.py
#       2
# ----> 3 from fpdf import FPDF
#       4
#       5 pdf = FPDF()
#
# ModuleNotFoundError: No module named 'fpdf'

# %%
type(g)

# %%
g.to_excel("C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\CGWB\\CGWB ANALYSIS REPORT.xlsx")

# %%
xl_file=pd.ExcelFile("C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\CGWB\\CGWB-District wise rainfall distribution in  Karnataka.xlsx",)

# %%
df_agroclimatezone=pd.read_excel(xl_file,sheet_name='Sheet3',index_col=None)
df_agroclimatezone

# %%
df_agroclimatezone.replace(to_replace='-',value=0,inplace=True)

# %%
df_agroclimatezone.dropna(thresh=2,axis=0,inplace=True)

# %%
df_agroclimatezone.reset_index(drop=True,inplace=True)
df_agroclimatezone

# %%
df_agroclimatezone

# %%
df_agroclimatezone.columns=['District','Bellary','Bidar','Chitradurga','Gulbarga','Kolar','Raichur','TOTAL']

# %%
df_agroclimatezone.drop(0,axis=0,inplace=True)

# %%
df_agroclimatezone.reset_index()

# %%
df_agroclimatezone.set_index('District',inplace=True)

# %%
df_agroclimatezone.iloc[[0,8,16],np.arange(0,6,1)].index[1]
#from mpl_toolkits import mplot3d

# %%
#'C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\CGWB\\Formation-Wise Distribution of Ground Water Level Monitoring Stations.pdf'

fig=plt.figure(figsize=(12,8))
ax1=df_agroclimatezone.iloc[[0,8,16],np.arange(0,6,1)].plot.bar(colormap='plasma',figsize=(12,8))
ax1.set_xlabel("year wies distribution of stations".upper(),size=14)
ax1.set_ylabel("NO. OF STATIONS",size=14)
ax1.set_title("Formation-Wise Distribution of Ground Water Level Monitoring Stations".upper(),size=16,)
plt.xticks(rotation=15,size=9,color='red')
plt.legend()

# %%
fig=plt.figure(figsize=(12,8))
ax2=df_agroclimatezone.iloc[[0,8,16],6].plot.bar(figsize=(12,8))
ax2.set_xlabel("year wies distribution of stations".upper(),size=14)
ax2.set_ylabel("NO. OF STATIONS",size=14)
ax2.set_title("total state Ground Water Level Monitoring Stations".upper(),size=16,)
plt.xticks(rotation=15,size=9,)
plt.legend()

# %%
dd={}
dd["Formation-Wise Distribution of Ground Water Level Monitoring Stations".upper()]=ax1.figure
dd["total state Ground Water Level Monitoring Stations".upper()]=ax2.figure
dd

# %%
# important
with PdfPages ("C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\CGWB\\Formation-Wise Distribution of Ground Water Level Monitoring Stations.pdf") as pdf:
    for var in dd.keys():
        pdf.savefig(dd[var])

# %%
data2=pd.read_excel(xl_file,sheet_name='Sheet4',index_col=None)

# %%
data2

# %%
data2.reset_index(drop=False,inplace=True)

# %%
data2.columns=data2.iloc[0]

# %%
data2.drop(0,axis=0,inplace=True)

# %%
data2.reset_index(drop=True,inplace=True)

# %%
data2.set_index('District',drop=True,inplace=True)

# %%
data2["remaining_stations_in_karnataka"]=data2['TOTAL']-data2['Bellary']-data2['Bidar']-data2['Chitradurga']-data2['Gulbarga']-data2['Kolar']-data2['Raichur']

# %%
data2 .drop('TOTAL',axis=1,inplace=True)

# %%
data2.iloc[4].plot.pie(figsize=(12,6),colormap='cividis',explode=(0,0.2,0,0,0.1,0.2,0),autopct='%1.1f%%',sharex=False,sharey=False)

# %%
data2.iloc[4].plot.bar(figsize=(12,6),sharex=True,sharey=True)
for x,y in zip(data2.columns,data2.iloc[4]):
    plt.text(x+0.04,y+0.005,'%.2f' % y,ha="center",va="bottom")
