# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
xls=pd.ExcelFile("C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\4th MI- Integrated table.xlsx")
df1=pd.read_excel(xls,'page 1',index_col=None,)

# %%
df1.head(10)
df1.shape
# Out:
# (41, 18)

# %%
df1.dropna(thresh=10,axis=1,inplace=True)
df1.dropna(thresh=6,axis=0,inplace=True)
df1=df1.iloc[5:41]

# %%
MISAG=pd.DataFrame(df1)
MISAG.reset_index
misag=MISAG.copy(deep=True)

misag.set_index('Unnamed: 1',inplace=True)
misag.columns
# Out:
# Index(['State Name:', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
misag.drop('State Name:',axis=1,inplace=True)

# %%
misag.columns
# Out:
# Index(['Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
misag.columns=[["No. of Blocks","No. of Villages","Dugwell","Shallow Tubewell","Deepwell","Total '(G.W)'","S.Flow Scheme","S.Lift Scheme","Total '(S.W)'","Grand Total","No.of Villages Schedules"]]

# %%
misag.index
misag
# Out:
#                  No. of Blocks No. of Villages Dugwell Shallow Tubewell  \
# Unnamed: 1
# Bagalkote                    6             603    8841            29348
# Bangalore                    5             604      43            13937
# Bangalore Rural              8            1890    3248            43453
# Belgaum                     10            1173   56834            43484
# Bellary                      7             549    1232            22137
# Bidar                        5             636   11725            15265
# Bijapur                      5             644   35979            18335
# Chamaraja Nagara             4             461    3158            22849
# Chikmagalur                  7            1130     426            24212
# Chitradurga                  6            1047    1384            48715
# Dakshina Kannada             5             420   26083            15195
# Davanagere                   6             928      42            43184
# Dharwar                      5             395      24             9409
# Gadag                        5             329     125             9790
# Gulbarga                    10            1417   19652            14001
# Hassan                       8            2561     952            46392
# Haveri                       7             694     156            24428
# Kodagu                       3             296       1             1382
# Kolar                       11            3338    1194            60332
# Koppal                       4             630    1811            26596
# Mandya                       7            1481    3119            35709
# Mysore                       7            1339     662            26239
# Raichur                      5             884    4007             7666
# Shimoga                      7            1545    6227            20181
# Tumkur                      10            2731    9183           102535
# Udupi                        3             267   27727             2077
# Uttara Kannada              11            1344   20640             6376
# State Total:               177           29336  244475           733227
#
#                  Deepwell Total '(G.W)' S.Flow Scheme S.Lift Scheme  \
# Unnamed: 1
# Bagalkote               0         38189           125         13991
# Bangalore               0         13980           877           135
# Bangalore Rural         0         46701          1841           471
# Belgaum                 0        100318           771         16878
# Bellary                 0         23369           169          5345
# Bidar                   0         26990           162          2153
# Bijapur                 0         54314           219          4182
# Chamaraja Nagara        0         26007           166             6
# Chikmagalur             0         24638          1943          4075
# Chitradurga             0         50099           448            75
# Dakshina Kannada        0         41278           168          2858
# Davanagere              0         43226           524          5396
# Dharwar                 0          9433           697          1703
# Gadag                   0          9915            29          1771
# Gulbarga                0         33653           641          5913
# Hassan                  0         47344          5202          1252
# Haveri                  0         24584          1406          5761
# Kodagu                  0          1383           256          2480
# Kolar                   0         61526          5211           127
# Koppal                  0         28407           148          1618
# Mandya                  0         38828           319           190
# Mysore                  0         26901          1063           342
# Raichur                 0         11673           350          4280
# Shimoga                 0         26408          5114          3834
# Tumkur                  0        111718          2334            46
# Udupi                   0         29804           585          2411
# Uttara Kannada          0         27016          1911           804
# State Total:            0        977702         32679         88097
#
#                  Total '(S.W)' Grand Total No.of Villages Schedules
# Unnamed: 1
# Bagalkote                14116       52305                      603
# Bangalore                 1012       14992                      604
# Bangalore Rural           2312       49013                     1890
# Belgaum                  17649      117967                     1173
# Bellary                   5514       28883                      549
# Bidar                     2315       29305                      636
# Bijapur                   4401       58715                      644
# Chamaraja Nagara           172       26179                      461
# Chikmagalur               6018       30656                     1130
# Chitradurga                523       50622                     1047
# Dakshina Kannada          3026       44304                      420
# Davanagere                5920       49146                      928
# Dharwar                   2400       11833                      395
# Gadag                     1800       11715                      329
# Gulbarga                  6554       40207                     1417
# Hassan                    6454       53798                     2561
# Haveri                    7167       31751                      694
# Kodagu                    2736        4119                      296
# Kolar                     5338       66864                     3338
# Koppal                    1766       30173                      630
# Mandya                     509       39337                     1481
# Mysore                    1405       28306                     1339
# Raichur                   4630       16303                      884
# Shimoga                   8948       35356                     1545
# Tumkur                    2380      114098                     2731
# Udupi                     2996       32800                      267
# Uttara Kannada            2715       29731                     1344
# State Total:            120776     1098478                    29336

# %%
nek=misag.loc[['Bellary','Bidar','Chitradurga','Koppal','Gulbarga','Raichur','State Total:']]
nek
# Out:
#              No. of Blocks No. of Villages Dugwell Shallow Tubewell Deepwell  \
# Unnamed: 1
# Bellary                  7             549    1232            22137        0
# Bidar                    5             636   11725            15265        0
# Chitradurga              6            1047    1384            48715        0
# Koppal                   4             630    1811            26596        0
# Gulbarga                10            1417   19652            14001        0
# Raichur                  5             884    4007             7666        0
# State Total:           177           29336  244475           733227        0
#
#              Total '(G.W)' S.Flow Scheme S.Lift Scheme Total '(S.W)'  \
# Unnamed: 1
# Bellary              23369           169          5345          5514
# Bidar                26990           162          2153          2315
# Chitradurga          50099           448            75           523
# Koppal               28407           148          1618          1766
# Gulbarga             33653           641          5913          6554
# Raichur              11673           350          4280          4630
# State Total:        977702         32679         88097        120776
#
#              Grand Total No.of Villages Schedules
# Unnamed: 1
# Bellary            28883                      549
# Bidar              29305                      636
# Chitradurga        50622                     1047
# Koppal             30173                      630
# Gulbarga           40207                     1417
# Raichur            16303                      884
# State Total:     1098478                    29336

# %%
nek.drop("Deepwell",axis=1,inplace=True)
nek_per=(100* nek / nek.max()).astype(float).round(2)
# Out:
# C:\Users\ankit\Anaconda3\lib\site-packages\pandas\core\generic.py:3108: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
nek_per
# Out:
#              No. of Blocks No. of Villages Dugwell Shallow Tubewell  \
# Unnamed: 1
# Bellary               3.95            1.87    0.50             3.02
# Bidar                 2.82            2.17    4.80             2.08
# Chitradurga           3.39            3.57    0.57             6.64
# Koppal                2.26            2.15    0.74             3.63
# Gulbarga              5.65            4.83    8.04             1.91
# Raichur               2.82            3.01    1.64             1.05
# State Total:        100.00          100.00  100.00           100.00
#
#              Total '(G.W)' S.Flow Scheme S.Lift Scheme Total '(S.W)'  \
# Unnamed: 1
# Bellary               2.39          0.52          6.07          4.57
# Bidar                 2.76          0.50          2.44          1.92
# Chitradurga           5.12          1.37          0.09          0.43
# Koppal                2.91          0.45          1.84          1.46
# Gulbarga              3.44          1.96          6.71          5.43
# Raichur               1.19          1.07          4.86          3.83
# State Total:        100.00        100.00        100.00        100.00
#
#              Grand Total No.of Villages Schedules
# Unnamed: 1
# Bellary             2.63                     1.87
# Bidar               2.67                     2.17
# Chitradurga         4.61                     3.57
# Koppal              2.75                     2.15
# Gulbarga            3.66                     4.83
# Raichur             1.48                     3.01
# State Total:      100.00                   100.00

# %%
nek_per.drop("State Total:",inplace=True)

# %%
print(nek_per.reset_index())
# Out:
#     Unnamed: 1 No. of Blocks No. of Villages Dugwell Shallow Tubewell  \
# 0      Bellary          3.95            1.87    0.50             3.02
# 1        Bidar          2.82            2.17    4.80             2.08
# 2  Chitradurga          3.39            3.57    0.57             6.64
# 3       Koppal          2.26            2.15    0.74             3.63
# 4     Gulbarga          5.65            4.83    8.04             1.91
# 5      Raichur          2.82            3.01    1.64             1.05
#
#   Total '(G.W)' S.Flow Scheme S.Lift Scheme Total '(S.W)' Grand Total  \
# 0          2.39          0.52          6.07          4.57        2.63
# 1          2.76          0.50          2.44          1.92        2.67
# 2          5.12          1.37          0.09          0.43        4.61
# 3          2.91          0.45          1.84          1.46        2.75
# 4          3.44          1.96          6.71          5.43        3.66
# 5          1.19          1.07          4.86          3.83        1.48
#
#   No.of Villages Schedules
# 0                     1.87
# 1                     2.17
# 2                     3.57
# 3                     2.15
# 4                     4.83
# 5                     3.01

# %%
d={0:['Total_per_cover_by_6 district',],1:["rest_remaining_per",]}
for i in nek_per.columns:
    n=nek_per[i].sum().round(2)
    d[0].append(n)
    d[1].append((100-n).round(2))

# %%
nek_rest=pd.DataFrame(d)
nek_rest
# Out:
#                                 0                   1
# 0   Total_per_cover_by_6 district  rest_remaining_per
# 1                           20.89               79.11
# 2                            17.6                82.4
# 3                           16.29               83.71
# 4                           18.33               81.67
# 5                           17.81               82.19
# 6                            5.87               94.13
# 7                           22.01               77.99
# 8                           17.64               82.36
# 9                            17.8                82.2
# 10                           17.6                82.4

# %%
nek_per.reset_index(inplace=True)

# %%
nek_per=nek_per.T.copy()

# %%
nek_per.reset_index(inplace=True)
nek_per
# Out:
#                      level_0        0      1            2       3         4  \
# 0                 Unnamed: 1  Bellary  Bidar  Chitradurga  Koppal  Gulbarga
# 1              No. of Blocks     3.95   2.82         3.39    2.26      5.65
# 2            No. of Villages     1.87   2.17         3.57    2.15      4.83
# 3                    Dugwell      0.5    4.8         0.57    0.74      8.04
# 4           Shallow Tubewell     3.02   2.08         6.64    3.63      1.91
# 5              Total '(G.W)'     2.39   2.76         5.12    2.91      3.44
# 6              S.Flow Scheme     0.52    0.5         1.37    0.45      1.96
# 7              S.Lift Scheme     6.07   2.44         0.09    1.84      6.71
# 8              Total '(S.W)'     4.57   1.92         0.43    1.46      5.43
# 9                Grand Total     2.63   2.67         4.61    2.75      3.66
# 10  No.of Villages Schedules     1.87   2.17         3.57    2.15      4.83
#
#           5
# 0   Raichur
# 1      2.82
# 2      3.01
# 3      1.64
# 4      1.05
# 5      1.19
# 6      1.07
# 7      4.86
# 8      3.83
# 9      1.48
# 10     3.01

# %%
print(nek_rest.index)
print(nek_per.index)
print(nek_per.shape)
print(nek_rest.shape)
print(nek_per.dtypes)
print(nek_rest.dtypes)
# Out:
# RangeIndex(start=0, stop=11, step=1)
# RangeIndex(start=0, stop=11, step=1)
# (11, 7)
# (11, 2)
# level_0    object
# 0          object
# 1          object
# 2          object
# 3          object
# 4          object
# 5          object
# dtype: object
# 0    object
# 1    object
# dtype: object

# %%
df=pd.concat([nek_per,nek_rest],axis=1,ignore_index=True)
df
# Out:
#                            0        1      2            3       4         5  \
# 0                 Unnamed: 1  Bellary  Bidar  Chitradurga  Koppal  Gulbarga
# 1              No. of Blocks     3.95   2.82         3.39    2.26      5.65
# 2            No. of Villages     1.87   2.17         3.57    2.15      4.83
# 3                    Dugwell      0.5    4.8         0.57    0.74      8.04
# 4           Shallow Tubewell     3.02   2.08         6.64    3.63      1.91
# 5              Total '(G.W)'     2.39   2.76         5.12    2.91      3.44
# 6              S.Flow Scheme     0.52    0.5         1.37    0.45      1.96
# 7              S.Lift Scheme     6.07   2.44         0.09    1.84      6.71
# 8              Total '(S.W)'     4.57   1.92         0.43    1.46      5.43
# 9                Grand Total     2.63   2.67         4.61    2.75      3.66
# 10  No.of Villages Schedules     1.87   2.17         3.57    2.15      4.83
#
#           6                              7                   8
# 0   Raichur  Total_per_cover_by_6 district  rest_remaining_per
# 1      2.82                          20.89               79.11
# 2      3.01                           17.6                82.4
# 3      1.64                          16.29               83.71
# 4      1.05                          18.33               81.67
# 5      1.19                          17.81               82.19
# 6      1.07                           5.87               94.13
# 7      4.86                          22.01               77.99
# 8      3.83                          17.64               82.36
# 9      1.48                           17.8                82.2
# 10     3.01                           17.6                82.4

# %%
df.set_index(0,inplace=True)

# %%
df=df.T.copy()

# %%
df.set_index("Unnamed: 1",inplace=True)

# %%
df=df.apply(pd.to_numeric)
df.drop("Total_per_cover_by_6 district",axis=0,inplace=True)

# %%
df["No. of Blocks"].plot.pie(figsize=(12,6),colormap="plasma",explode=(0,0.3,0,0.2,0,0,0),autopct='%1.1f%%')

# %%
df["No. of Villages"].plot.pie(figsize=(12,6),colormap='inferno',explode=(0,0.3,0,0.1,0,0,0),autopct='%1.1f%%')

# %%
df["Dugwell"].plot.pie(figsize=(12,6),colormap='tab20',explode=(0,0.3,0,0.4,0,0,0),autopct='%1.1f%%')

# %%
df["Shallow Tubewell"].plot.pie(figsize=(12,6),colormap='winter',explode=(0,0.3,0,0.05,0,0.3,0),autopct='%1.1f%%')

# %%
df["Total '(G.W)'"].plot.pie(figsize=(12,6),colormap='viridis',explode=(0,0.3,0,0.05,0,0.05,0),autopct='%1.1f%%')

# %%
df["Grand Total"].plot.pie(figsize=(12,6),colormap='copper',explode=(0,0.3,0,0.2,0,0.2,0),autopct='%1.1f%%')

# %%
df["No.of Villages Schedules"].plot.pie(figsize=(12,6),colormap='spring',explode=(0,0.3,0,0.05,0.2,0,0),autopct='%1.1f%%')

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

with PdfPages('foo.pdf') as pdf:
   for i in df.index:
       plt.figure()
       fig=df.loc[i].plot.bar(figsize=(9,9)).get_figure()
       pdf.savefig(fig)

# %%
print(df.index)
print(df.columns)
colorsmap_list=["plasma",'inferno','tab20','winter','viridis','copper','spring','winter','inferno',"plasma"]
colorsmap_list[6]
# Out:
# Index(['Bellary', 'Bidar', 'Chitradurga', 'Koppal', 'Gulbarga', 'Raichur',
#        'rest_remaining_per'],
#       dtype='object', name='Unnamed: 1')
# Index(['No. of Blocks', 'No. of Villages', 'Dugwell', 'Shallow Tubewell',
#        'Total '(G.W)'', 'S.Flow Scheme', 'S.Lift Scheme', 'Total '(S.W)'',
#        'Grand Total', 'No.of Villages Schedules'],
#       dtype='object', name=0)
# 'spring'

# %%
count=0
with PdfPages('C:\\Users\\ankit\\Desktop\\DATA SCIENCE\\rakesh data files\\MINOR IRRIGATION  SCHEMES AT A GLANCE.pdf') as pdf:
    for i in df.columns:
        fig=plt.figure(num=count,figsize=(10,9))
        ax=df[i].plot.pie(colormap=colorsmap_list[count],explode=(0,0.3,0,0.2,0,0.075,0),autopct='%1.1f%%',)
        plt.title(i.upper())
        pdf.savefig(fig)
        plt.close()
        count+=1

count=0
